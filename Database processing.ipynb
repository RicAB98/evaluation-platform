# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
try:
    cnx = mysql.connector.connect(user='ricardo', 
                                  password='password',
                                  host='localhost',
                                  database='zerozero')

except mysql.connector.Error as err:
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  else:
    print(err)
    
    
#cnx.close()

# %%
cursor = cnx.cursor()
cursor.execute("Select * from zzlog_search where date > '2021-01-25' and date < '2021-02-10'")
rows = cursor.fetchall()
#while row is not None:
#    print(row)
#    row = cursor.fetchone()

# %%
df = pd.DataFrame (rows, columns=['id','time','date','method','page','referer','ip','sess_id','username','agent','language','bot','page_number','mysql_id','cache','server_ip','geo_location','search_string', 'tp_item', 'fk_item'])
#df

# %%
df
# Out:
#               id                time        date method  \
# 0       16821480 2021-01-26 00:00:00  2021-01-26   POST
# 1       16821481 2021-01-26 00:00:01  2021-01-26   POST
# 2       16821482 2021-01-26 00:00:08  2021-01-26   POST
# 3       16821483 2021-01-26 00:00:11  2021-01-26
# 4       16821484 2021-01-26 00:00:14  2021-01-26   POST
# ...          ...                 ...         ...    ...
# 568376  17389856 2021-02-09 23:59:40  2021-02-09
# 568377  17389857 2021-02-09 23:59:46  2021-02-09
# 568378  17389858 2021-02-09 23:59:49  2021-02-09
# 568379  17389859 2021-02-09 23:59:57  2021-02-09   POST
# 568380  17389860 2021-02-09 23:59:58  2021-02-09   POST
#
#                                                      page  \
# 0                          jogador.php?id=408631&search=1
# 1                                 team.php?id=19&search=1
# 2                               team.php?id=2299&search=1
# 3       https://www.zerozero.pt/search.php?inputstring...
# ...

# %%
df.to_csv('logs.csv', index = False)
